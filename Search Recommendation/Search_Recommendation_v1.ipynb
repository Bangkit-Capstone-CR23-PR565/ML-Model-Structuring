# %%
import pandas as pd
events_df = pd.read_csv("https://api.mockaroo.com/api/3f045400?count=1000&key=9aadb790")
data = events_df['tags'].tolist()

# %%
data = [d.strip("{}") for d in data]

# %%
data
# Out:
# ['Nature  Pop_Culture Beauty Music Literature Religion',
#  'Photography  Religion Finance Environment Finance Social_Media',
#  'Education  Pop_Culture Literature Entertainment Art',
#  'Charity  Health Science Education Parenting Food Literature Human_Rights',
#  'Environment  Human_Rights Gaming Fashion Charity Fitness Business Marketing Social_Media',
#  'Gardening ',
#  'Religion  Technology Education Gaming Nature Social_Media Education Travel Fitness',
#  'Environment  Travel DIY Fashion Fashion Fashion Education Social_Media',
#  'Environment  Nature Literature Music Photography DIY Health',
#  'Religion  Sports',
#  'Pop_Culture  Business Religion Environment Food Marketing',
#  'Fashion  Parenting Gaming Science Education Entertainment Entertainment',
#  'Photography  Gardening Literature Nature Health Politics Health Health Politics Social_Media Pop_Culture',
#  'DIY  Pop_Culture Charity Parenting Entertainment',
#  'Sports  Entertainment Gardening',
#  'Health  Fitness Social_Media Education Beauty Fashion Business Religion Music',
#  'Charity  Fashion Social_Media',
#  'Crafts  Entertainment Music Business Social_Media Fitness Parenting Parenting Beauty',
#  'Education  Social_Media Music Education',
#  'Politics  Business Music Parenting Crafts Politics Music Environment Crafts Photography',
#  'Politics  Technology Health Business',
#  'Beauty  Music Pop_Culture Entertainment Literature Science Parenting Education Business Health Beauty',
#  'Entertainment  Music DIY Food Food Pop_Culture Human_Rights Beauty Entertainment Pop_Culture',
#  'Fashion  Art Crafts Nature DIY Technology Pop_Culture',
#  'Environment  Gaming Food Science Music',
#  'Sports  Marketing DIY Environment Social_Media Technology',
#  'Music  Beauty Marketing Pop_Culture Environment Fitness Parenting Science',
#  'Religion  Sports Food Photography',
#  'Food  Fitness Parenting Pop_Culture Health Sports Parenting',
#  'Social_Media  Travel Nature Food Marketing Religion',
#  'Pop_Culture  Art',
#  'Education  Nature Entertainment Fashion',
#  'Technology  Parenting Parenting Beauty',
#  'Science  Human_Rights Art Charity Technology Crafts Education Business',
#  'Food  Nature Photography',
#  'Politics  Human_Rights Parenting Sports',
#  'Food  Finance Pop_Culture Technology Health Food Pop_Culture Entertainment Health',
#  'Social_Media ',
#  'Food  Business Literature Education Beauty Human_Rights',
#  'Nature  Crafts Travel Art Gaming Health Human_Rights Fitness',
#  'Fashion  DIY Charity Travel Photography DIY Technology Charity',
#  'Charity  Parenting Fitness Finance Science Food Music Business Travel Art',
#  'Entertainment  DIY Finance Religion Education Music Photography',
#  'Parenting  Fashion Charity Sports Sports',
#  'Fashion  Science Education',
#  'Business  Entertainment Fashion Social_Media Environment Nature Sports Entertainment',
#  'Fashion ',
#  'Fashion  Education',
#  'Charity  Gaming Sports Art Music',
#  'Nature  Crafts Gardening Business Fitness Fitness Music Beauty Environment',
#  'Science  Environment',
#  'Fitness  Education',
#  'Food  Fashion Marketing Entertainment Gaming Nature',
#  'Social_Media  Finance Music Politics Technology Beauty Pop_Culture Art DIY Pop_Culture Charity',
#  'Social_Media  Social_Media Food Music Photography Pop_Culture Gaming Food',
#  'Gardening  Travel Marketing Politics',
#  'Photography  Finance Photography Marketing Health Nature Social_Media Crafts',
#  'Marketing  Pop_Culture',
#  'Beauty  Parenting Sports Entertainment Education Social_Media Technology Education Sports Parenting',
#  'Human_Rights  Finance Entertainment DIY Sports Fashion Gardening Gardening Health Marketing',
#  'Environment  Beauty Charity',
#  'Gaming  Fashion Photography Fashion Art',
#  'Sports  Gaming Politics Entertainment Beauty Travel Photography',
#  'Pop_Culture  Gaming Social_Media Fitness Human_Rights Gaming Finance Crafts Politics',
#  'Human_Rights  Gardening Social_Media Technology Technology Technology Fashion Fitness',
#  'Science  Pop_Culture Charity Art Entertainment Beauty Pop_Culture Business Entertainment',
#  'Charity  Nature',
#  'Fashion  Gaming',
#  'Crafts  Fitness Parenting Environment Beauty Photography Business Health',
#  'Gaming  Religion Sports Nature',
#  'Charity  Fitness Environment Environment Photography Politics Literature Social_Media Travel Nature Crafts',
#  'Education  Religion Entertainment Art Entertainment Gaming Fashion Technology Charity',
#  'Fitness  Human_Rights Literature Travel Human_Rights Photography Music Crafts Education',
#  'Literature  Nature',
#  'Crafts  Religion Gardening Marketing Crafts Religion',
#  'Gardening  Technology Entertainment Charity Environment Music Entertainment Social_Media Food Environment',
#  'Fitness  Charity Beauty Art',
#  'Gaming  Photography Music DIY',
#  'Fashion  Parenting Technology Travel Music Pop_Culture DIY',
#  'Health  Entertainment Art Fashion',
#  'Business  Gardening Art Social_Media Religion Education Sports Nature Social_Media Human_Rights Marketing',
#  'Crafts  Fitness',
#  'Marketing  DIY Education Politics Nature Entertainment Fashion Technology Technology',
#  'Human_Rights  Gardening Pop_Culture Art Social_Media DIY Finance Nature',
#  'Travel  Finance Sports Literature Social_Media Art Religion Photography Environment Charity',
#  'Food  Technology DIY Business Technology',
#  'Science ',
#  'Social_Media  Gardening Finance',
#  'Photography  Entertainment Technology',
#  'Business ',
#  'Technology  Health Charity Beauty Finance Social_Media Art',
#  'Music  Art Finance Music Travel Science Politics Pop_Culture Gaming Fitness',
#  'Literature  Social_Media Business Pop_Culture Music Technology Travel',
#  'Fashion  Art Parenting Technology Charity Pop_Culture Gaming Beauty',
#  'Fitness  Gardening Photography',
#  'Pop_Culture  Literature Gaming Education Beauty Politics Travel Pop_Culture',
#  'Health  Nature Human_Rights Gaming Human_Rights Fashion Environment Gaming',
#  'Photography  Art Marketing Finance Science Environment',
#  'Crafts  Fashion Environment Science Gaming Business Gardening Finance',
#  'Human_Rights  Charity Education Health Entertainment Marketing Entertainment Crafts',
#  'Sports  Art Music Charity Science Literature Fashion Photography Education Literature DIY',
#  'Politics  Environment Photography Business Education Education',
#  'Marketing  Charity Health Charity Education Science',
#  'Fashion  Politics Entertainment Business',
#  'Parenting ',
#  'Beauty  Photography Religion Gardening',
#  'Sports  Sports DIY DIY Art Fitness Science Business Travel Music Science',
#  'Finance  Politics',
#  'Human_Rights  Technology Education Technology Art Technology',
#  'Sports  Photography Politics Crafts',
#  'Social_Media  Sports Human_Rights',
#  'Crafts  Entertainment Music Science Parenting Marketing DIY Religion Entertainment',
#  'Gardening  Charity Art Literature Politics Beauty Crafts Crafts Fashion',
#  'Health  Environment Business Charity',
#  'Parenting  Gaming DIY Crafts Fitness Travel Gaming',
#  'Health  Photography Literature',
#  'Beauty  Politics Fitness Technology',
#  'Entertainment ',
#  'Crafts  Social_Media Food',
#  'Social_Media ',
#  'Environment  Gaming Crafts Marketing Beauty Fashion Education Finance Politics Gardening',
#  'Fitness  Beauty Parenting Charity Fitness DIY',
#  'Pop_Culture  Social_Media',
#  'Art  Food DIY Science Finance Entertainment',
#  'Pop_Culture  Nature',
#  'Pop_Culture  Literature Health Health Entertainment Charity Fitness',
#  'Finance  Nature Gardening Finance',
#  'Education  Beauty Business Nature Education Entertainment Photography Gaming',
#  'DIY  Religion Travel Health Pop_Culture Entertainment',
#  'Business ',
#  'Health  Fashion Nature Education Travel Beauty Business Crafts Social_Media Charity',
#  'Gardening  Nature Literature',
#  'Food  Fashion Art Finance Science Charity Photography Health Entertainment Education Entertainment',
#  'Travel ',
#  'Sports  Fitness Entertainment Politics',
#  'Literature  Fashion',
#  'Literature  Fashion Environment Gaming Crafts Art Social_Media Education Literature Technology',
#  'Business  Science Religion Entertainment Finance',
#  'Gardening  Fitness Parenting Charity Sports Travel Religion Sports Science Marketing',
#  'Health  DIY Food Charity Fitness Sports Religion Parenting Finance Photography Art',
#  'Sports  Crafts Nature Food Photography Health Travel Sports Religion Food',
#  'Sports  Finance Science Travel Parenting Gaming Technology',
#  'Parenting  Music Science Sports Gardening Charity Business',
#  'Nature  Social_Media Beauty Pop_Culture Politics Sports',
#  'Fitness  DIY',
#  'Marketing  Social_Media Fashion Gaming',
#  'Business  Gaming Beauty Fitness Fashion Finance',
#  'Marketing  Gardening Photography Religion Environment Social_Media Pop_Culture Religion Gaming',
#  'Science  Social_Media Literature Music Politics DIY Politics Gardening Gardening Fashion',
#  'DIY  DIY Nature Human_Rights',
#  'Art ',
#  'Technology  Business Entertainment Photography Beauty Politics',
#  'Science  Science Gaming',
#  'Parenting  Parenting Religion Marketing Politics Nature Beauty Health Gardening Marketing',
#  'Fitness  Marketing Technology Science Religion Education Beauty Marketing Fashion Environment',
#  'Nature  Gaming Photography Fashion Beauty Gaming Entertainment Parenting DIY',
#  'Crafts ',
#  'Nature  Gaming Pop_Culture Charity Social_Media Gaming Beauty',
#  'Music  Beauty Sports',
#  'Fitness  Science Marketing Pop_Culture Human_Rights Food Marketing',
#  'Finance  Marketing Environment Fashion',
#  'Technology  Education Religion DIY Nature Politics',
#  'Art  Science Business Human_Rights Human_Rights',
#  'Technology  Health',
#  'Literature  Fitness Pop_Culture',
#  'DIY  Nature Photography',
#  'Gardening  Education',
#  'Photography  Art Finance Fitness Education Crafts Travel DIY Charity Politics',
#  'Food  Environment Food Politics Environment',
#  'Religion  Technology',
#  'Human_Rights  Music Science Parenting Gardening Entertainment Human_Rights Human_Rights',
#  'Health ',
#  'Parenting  Religion Music Environment',
#  'Crafts  Environment Photography DIY Travel Food Nature',
#  'Religion  Photography Entertainment Crafts Technology',
#  'Nature  Art Entertainment Technology Fashion Travel Environment Business Gaming Photography Fitness',
#  'Entertainment  Politics Technology Business Photography Art Social_Media Human_Rights Social_Media',
#  'Science  DIY Nature Environment Education Education',
#  'DIY  Human_Rights Beauty Charity Finance',
#  'Gardening  Music Parenting Music Photography Human_Rights Health Fitness DIY Literature Music',
#  'Art  Gardening Science Human_Rights Nature',
#  'Photography  Gardening Parenting Travel Food',
#  'Science  Human_Rights Technology Politics Travel Sports Music',
#  'Social_Media  Fitness Human_Rights Sports Technology Nature Human_Rights DIY Literature Business',
#  'Sports  Business Gardening Environment Photography Music Fitness Gardening Human_Rights',
#  'Environment  Entertainment Beauty Marketing Religion Music Science Business Science',
#  'Nature  Literature Gaming Music',
#  'DIY  Education',
#  'Health  Photography Technology Technology Food DIY Fitness',
#  'Gardening  Human_Rights Crafts Crafts Sports Technology Gardening Pop_Culture Finance Finance Business',
#  'Gardening  Art Fitness Health Business Technology Business',
#  'Beauty  Literature Art Marketing',
#  'Literature  Crafts Politics Finance Health Fashion Gardening Gaming Fitness',
#  'Literature  Pop_Culture Photography Social_Media Gaming Science',
#  'Education  Food',
#  'Charity  Environment Human_Rights Travel',
#  'Business  DIY Literature Food Finance Photography',
#  'Social_Media  Gardening Marketing Photography Beauty Human_Rights Charity',
#  'Photography  Parenting Sports Science Photography Human_Rights Human_Rights Entertainment Human_Rights Charity Fitness',
#  'Food  Fitness Education Nature Food Travel Fashion Parenting DIY Entertainment Sports',
#  'Photography  Science Science',
#  'Gardening  Parenting Art Human_Rights Technology Gaming Gaming Charity Charity Environment',
#  'Fitness  Fashion Fitness Environment Health Gardening Sports Education Pop_Culture Entertainment',
#  'Gaming  Business Fashion Science Food Fitness Human_Rights Marketing',
#  'Nature  Human_Rights Photography Photography Travel Crafts Fashion Fitness Health',
#  'Travel  Science Sports Food Politics Crafts',
#  'Art  Crafts Sports Travel Entertainment Pop_Culture',
#  'Business  Photography Politics Crafts',
#  'Marketing  Beauty Human_Rights Art Crafts Beauty Finance Pop_Culture',
#  'Pop_Culture  DIY Social_Media Science Art Business Literature Social_Media Education Crafts Human_Rights',
#  'Travel  DIY Religion DIY Marketing Beauty Food Religion Business Religion Fashion',
#  'Entertainment  Education Health Business Parenting Fashion Finance Art Parenting',
#  'Charity  Education Nature Health Pop_Culture DIY',
#  'Religion  Fashion Gardening Travel Fitness Fitness Music',
#  'Finance  Sports',
#  'Crafts  Science Literature Parenting Human_Rights Finance Entertainment Crafts Social_Media Gaming Charity',
#  'Gardening  Nature Environment',
#  'Food  Fashion',
#  'DIY  Religion Music Politics',
#  'Parenting  Literature Music Food Fashion Education Health Beauty Sports',
#  'Human_Rights  Education Human_Rights Technology',
#  'Fitness  Business',
#  'Gardening  Music Crafts Environment Religion',
#  'Science  Beauty Environment Pop_Culture Health Sports Travel Gaming',
#  'Science  Fashion Technology Environment Photography DIY',
#  'Science  Art Religion Social_Media Education Environment Photography Fashion Fashion Technology Literature',
#  'Social_Media  Religion Photography Marketing Nature',
#  'Art  Fashion',
#  'Pop_Culture  Marketing Education Environment Gardening Religion Education Technology DIY',
#  'Fashion  Music Pop_Culture Social_Media Parenting Business Marketing Art Marketing Nature',
#  'Gardening  Gaming Gardening Business Art Business Gaming Technology Pop_Culture',
#  'Technology ',
#  'Education  Technology Gardening Nature',
#  'Art  Food Human_Rights Health Business Charity Finance Health Charity',
#  'Technology  Food Sports Social_Media Charity',
#  'Literature  Religion Religion Social_Media Art Politics',
#  'Pop_Culture  Art Music Sports Politics Science Human_Rights Literature',
#  'Photography  DIY Music Human_Rights Parenting Fashion Gardening',
#  'Beauty  Literature Pop_Culture Fashion Fitness Human_Rights Education DIY Photography',
#  'Gaming  Travel Travel Fitness Environment Crafts',
#  'Social_Media  Science DIY Beauty Pop_Culture Gardening Parenting Pop_Culture Social_Media Entertainment Politics',
#  'Travel  Health Gardening Marketing Beauty Technology Travel',
#  'Fashion  Politics Pop_Culture Gaming Science Travel Entertainment',
#  'DIY  Health Parenting Pop_Culture Gardening Music Sports Fitness Pop_Culture Charity',
#  'Human_Rights  Art Education Literature Politics Gaming Business Music',
#  'Art  Photography Environment Nature',
#  'Nature  Nature',
#  'Crafts  Beauty Pop_Culture Beauty Gaming',
#  'Social_Media  Music Literature Social_Media Human_Rights Technology',
#  'Art  DIY',
#  'Environment  Music Marketing',
#  'Environment ',
#  'Entertainment  Technology Social_Media',
#  'Travel  Sports Music Business Entertainment',
#  'Technology  Nature',
#  'Music ',
#  'Food  Gardening Fitness Education Business Finance Finance',
#  'Environment  Art Gaming',
#  'Finance  Religion Religion Crafts',
#  'Business  Gaming Nature Pop_Culture Religion Marketing Art Nature Health',
#  'Education  DIY Gaming Politics Crafts Crafts Fitness Fitness Religion Fashion',
#  'Art ',
#  'Education  Food Charity Charity Literature Fashion Education',
#  'Environment ',
#  'Nature  Politics Fitness Technology Marketing Sports Nature DIY',
#  'Fashion  Pop_Culture Finance Business Food',
#  'Crafts ',
#  'Human_Rights  Business Finance Marketing Environment Marketing',
#  'Entertainment  Education Pop_Culture Parenting Nature',
#  'Business  Business Fashion',
#  'Art  Photography Food Food',
#  'Music  Religion Fitness Gardening Finance Pop_Culture Social_Media',
#  'Education  Nature Crafts Music Religion Pop_Culture Literature DIY Health Food',
#  'Crafts  Pop_Culture Social_Media Entertainment Beauty Technology Sports',
#  'Human_Rights  Science Health Literature Gardening Literature Food Education Human_Rights Human_Rights',
#  'Fashion  Environment Business Travel Travel Food Marketing Photography',
#  'Health  DIY Health',
#  'Technology  Music Politics Music DIY Parenting Pop_Culture',
#  'Health  Literature',
#  'Social_Media  Pop_Culture Human_Rights Technology Fashion DIY Entertainment Business Crafts Religion',
#  'Art  Human_Rights Human_Rights Environment Human_Rights Education Gardening Sports Gardening',
#  'Business  Fitness Parenting Business Photography Health Parenting Politics',
#  'Science  Religion Beauty Fashion Literature',
#  'Pop_Culture  Literature Human_Rights Religion Nature',
#  'Marketing  Health Nature Art Religion Crafts Pop_Culture',
#  'Religion  Science Entertainment Fitness Parenting Pop_Culture Marketing',
#  'Fitness  Fitness Finance Environment Art',
#  'Health  Parenting Social_Media Entertainment Politics Finance DIY Marketing Photography',
#  'Health ',
#  'Finance  Health Social_Media Health Food Crafts Education',
#  'Science  Health Finance Nature Education Charity Literature Music',
#  'Business  Politics Beauty Charity',
#  'Fashion  Fitness',
#  'Fitness  Politics DIY Environment Nature Parenting Religion Parenting Gardening Finance Parenting',
#  'DIY  Religion Parenting Sports Human_Rights Finance Photography Gardening',
#  'Technology  Travel Environment Fashion Marketing Entertainment DIY Business Gaming',
#  'Entertainment  Music Health Finance Crafts Parenting Photography Photography Business',
#  'Photography  Sports Politics Business Finance Environment Art Education Finance Sports',
#  'Charity  Human_Rights DIY Literature Nature Technology',
#  'Travel  Education Nature Nature Sports Music Fitness Marketing Pop_Culture Fitness',
#  'Literature  Social_Media Finance',
#  'Environment  Music Pop_Culture Technology Nature Literature Human_Rights Gaming Environment Science Marketing',
#  'Technology  Social_Media Charity Parenting Gaming Art Marketing Beauty Sports Finance Finance',
#  'Beauty  Technology',
#  'Environment  Beauty Marketing Human_Rights Literature Fitness',
#  'Fashion  Environment',
#  'Photography  Music Gaming Art Politics Environment Crafts Nature Health Technology',
#  'Marketing  Religion Gaming Food Gardening Technology',
#  'Human_Rights  Business Technology Education Sports Parenting Religion Entertainment Finance Art Environment',
#  'Entertainment  Sports Politics',
#  'Fashion  Travel',
#  'Gardening  Social_Media Health Music Health',
#  'Education  Food Literature Technology',
#  'Health  Photography Beauty Music Gardening Finance',
#  'Photography ',
#  'DIY  Science',
#  'Crafts  Marketing',
#  'Politics  Photography DIY Nature',
#  'Environment  Politics',
#  'Nature  Music Education Politics Human_Rights Pop_Culture Business',
#  'Pop_Culture ',
#  'Gaming  Environment Science Business Social_Media Parenting Education Health Crafts Religion',
#  'Environment  Music Parenting',
#  'Education  Parenting Fitness',
#  'Health  Education Technology Fashion Gardening Crafts Finance Parenting Crafts',
#  'Environment  Politics Politics DIY Fitness Fashion Gardening Finance Human_Rights Gardening',
#  'Travel  Environment Technology Human_Rights',
#  'Pop_Culture  Health Finance',
#  'Music  Fitness Technology Health Social_Media Art Social_Media Fitness',
#  'Nature  Sports Travel Religion Politics',
#  'Beauty  Technology Gaming DIY Photography',
#  'Photography  Human_Rights Politics Beauty Technology Beauty',
#  'Crafts ',
#  'Literature  Crafts Charity Religion DIY Parenting Marketing Science Social_Media Health Pop_Culture',
#  'Science  Sports DIY',
#  'Education ',
#  'Technology  Finance',
#  'Fashion  Education Music Fitness Finance Politics Art Entertainment Gardening Finance Travel',
#  'Environment  Marketing Literature Technology Human_Rights Marketing DIY Sports Pop_Culture Science Science',
#  'Photography  Food Literature Sports',
#  'Education  Charity Human_Rights Travel Crafts Music',
#  'Human_Rights  Health Pop_Culture Religion Business Finance Gaming',
#  'Parenting  Religion Fashion Parenting Education',
#  'Marketing  Marketing Food',
#  'Environment ',
#  'Pop_Culture ',
#  'Food  Nature DIY Health Food Science Education',
#  'Nature  Photography Music Politics Art Fashion',
#  'Human_Rights  Marketing Business Music Human_Rights Marketing Finance Education Gaming Entertainment',
#  'Food ',
#  'Crafts  Pop_Culture Fitness Religion Education Literature Photography',
#  'Gardening  Food DIY Charity Technology Business',
#  'Sports ',
#  'Fashion  Gaming Parenting Travel Pop_Culture Fashion Parenting',
#  'Entertainment  DIY Charity Nature Social_Media Human_Rights Nature Parenting',
#  'Crafts  Literature Business Health Sports Social_Media DIY Religion Health Gaming Education',
#  'Education  DIY Art Politics Parenting',
#  'Education  Environment Travel Crafts Gaming Parenting',
#  'Finance  Beauty Music Health Science Nature Fitness Health Environment Beauty',
#  'Environment  Religion Technology Technology Education Charity Religion Parenting Human_Rights Health Education',
#  'Finance  Human_Rights Fitness',
#  'Technology  Art Environment Sports Gardening',
#  'Art  Pop_Culture Education Nature Technology Fitness Travel Social_Media Technology',
#  'Crafts  Finance Gaming Beauty Travel Sports Parenting Literature',
#  'Art  Human_Rights Art',
#  'Parenting  Science Food Literature Technology Gardening',
#  'Pop_Culture  Art Music',
#  'Environment  Nature DIY Parenting Music Gardening Fitness Photography Education',
#  'Literature  Human_Rights Charity Fitness Music Health Crafts',
#  'Parenting  Marketing Art Science Gardening',
#  'Parenting ',
#  'Education  DIY Photography Art Literature Entertainment DIY Music Gardening Art Marketing',
#  'Business  Entertainment Sports Education Photography Food Politics Beauty',
#  'Gaming  Art Nature Literature Politics Nature Travel Art Food',
#  'Food  Food Parenting Literature',
#  'Business  Social_Media Finance Sports Crafts DIY Food Food Travel Beauty Science',
#  'DIY  Art',
#  'Religion  Food Politics DIY Pop_Culture',
#  'Social_Media  Crafts Fitness Finance Pop_Culture',
#  'Technology  Travel Technology Fitness Business Business Finance Pop_Culture Parenting Human_Rights Charity',
#  'Fashion  Politics Photography Business Photography Pop_Culture Charity Charity',
#  'Social_Media  Health Literature Sports Art',
#  'Sports ',
#  'Pop_Culture  Social_Media Fashion DIY',
#  'Art  Human_Rights Fashion Nature Environment Finance Entertainment Fitness Politics Finance Art',
#  'Music  Technology Fashion Human_Rights Religion Politics Environment Parenting Photography Literature',
#  'Environment  Charity Fitness',
#  'Charity  Literature Gardening Science Fitness DIY Gardening Science',
#  'Business  Travel Marketing Art Business',
#  'Religion  Marketing',
#  'Music  Crafts Crafts Charity Human_Rights Pop_Culture Pop_Culture Literature Literature Gardening',
#  'Sports  Gardening Business Education Social_Media Charity Education Photography Marketing',
#  'Beauty  Pop_Culture',
#  'Finance  Parenting Entertainment Environment Health Art Education Crafts Politics Gardening',
#  'Nature ',
#  'Business  Food',
#  'Music  Health Education Entertainment Science',
#  'Fashion ',
#  'Marketing  Science Religion Literature Fashion Sports Beauty Religion DIY Literature',
#  'Human_Rights  Charity Technology Gardening Human_Rights Politics Photography',
#  'Religion  Beauty',
#  'Fitness  DIY Fitness Travel DIY Education Science Music',
#  'Religion  Fashion Gardening Gardening',
#  'Religion  Travel Human_Rights Sports Religion',
#  'Beauty  Food Beauty',
#  'Food  Science Politics Gaming Fashion',
#  'Science  Pop_Culture DIY',
#  'Photography  Art Crafts Politics Music',
#  'Education ',
#  'Business  Politics Science Sports Charity Science Fashion Nature Crafts Business Nature',
#  'Marketing  Entertainment Crafts Parenting Marketing',
#  'Food  Education Gaming Health Sports Travel Politics Literature Education Gaming',
#  'Business  Charity Pop_Culture Finance Health Travel Politics',
#  'Photography  Environment Food Health Environment Entertainment',
#  'Art ',
#  'Charity ',
#  'Gardening  Religion Politics Gaming Beauty Gardening Fitness Beauty Business',
#  'Crafts  Crafts Gardening Gardening Pop_Culture Nature Social_Media Sports Nature Environment Health',
#  'Sports  Finance Environment Finance Business Crafts Art Technology DIY Photography Travel',
#  'Travel  Gardening Crafts Politics Sports',
#  'Nature  Fitness Science Parenting Education Art Human_Rights Technology Crafts Gaming',
#  'Marketing  Sports Gaming Fitness Fashion Religion Environment Charity Fashion Health',
#  'Technology  Fashion Gaming Photography',
#  'Marketing ',
#  'Sports  Crafts Photography Business Gardening',
#  'Literature  Marketing Education',
#  'Education  Charity DIY Gaming Music Charity Gardening Environment Entertainment Environment Finance',
#  'Crafts  Photography Gaming Environment Travel Fashion Environment Crafts Food Entertainment',
#  'Food  Sports DIY Travel',
#  'Food  Politics Health Nature Human_Rights Parenting Education Environment Politics Science',
#  'Environment ',
#  'Beauty  Parenting Sports Gaming Technology Beauty',
#  'Travel  Music Environment Art Finance Entertainment Finance Social_Media Human_Rights',
#  'Education  Parenting Entertainment Politics Human_Rights Business Health Parenting',
#  'Charity ',
#  'Parenting  Human_Rights Music Social_Media Science Pop_Culture Business Charity Beauty',
#  'Sports  Gaming Food Sports Education Entertainment Politics Parenting Music Fitness Crafts',
#  'Travel  Marketing Science Religion Environment Nature Politics Music Pop_Culture Nature',
#  'Politics  Beauty Beauty Social_Media',
#  'Health  Fitness Fashion Crafts Fashion',
#  'Crafts  Business Education Nature Fitness Marketing Art Nature Sports Crafts',
#  'Music  Entertainment Marketing',
#  'Travel  Social_Media Literature Food Social_Media Gaming',
#  'Human_Rights ',
#  'Beauty  Technology',
#  'Marketing  Sports Human_Rights Literature Food Politics',
#  'Human_Rights  Fashion Business Technology',
#  'Art  Health Fashion Sports Politics',
#  'Gardening  Music Human_Rights Fashion Sports',
#  'Fashion  Fitness Environment Technology Fitness Literature Human_Rights Art Environment Literature',
#  'Finance  Music Finance Human_Rights Food',
#  'Charity  Charity Marketing Crafts',
#  'Religion  DIY Beauty Politics Parenting',
#  'Finance  Technology Photography Charity Human_Rights Music Social_Media Gaming Travel',
#  'Music  Gaming',
#  'Environment  Food Science Human_Rights Environment Gardening',
#  'Crafts  Fashion Human_Rights Technology Nature Sports Fitness Education Food',
#  'Human_Rights  Politics Technology Gaming Parenting Crafts',
#  'Beauty  Religion Photography Environment Pop_Culture',
#  'Entertainment  Education',
#  'Health  Gardening Charity Politics Religion Crafts Parenting Food Technology',
#  'Human_Rights  Food Fitness Social_Media Human_Rights',
#  'Charity  Pop_Culture Social_Media Business Human_Rights Food DIY Gaming Music Social_Media',
#  'Music  Religion Sports Parenting',
#  'Beauty  Art',
#  'Beauty  Gaming Fitness Technology Health Gardening Music Environment Politics Art Social_Media',
#  'Beauty  Photography Travel Beauty Business Beauty Literature Music Photography Gaming',
#  'DIY  Finance Nature Gardening Entertainment Marketing Gardening',
#  'Fashion  Finance Environment Gardening',
#  'Gardening  Entertainment Charity Nature Art Beauty',
#  'Health  Fitness Sports Travel Food Food Gaming',
#  'Technology  Parenting Photography Charity Art Marketing Social_Media Religion Business Pop_Culture Marketing',
#  'Finance  Health Photography Parenting Travel Pop_Culture Gaming Nature Social_Media DIY',
#  'Gardening  Fashion Fitness Nature Social_Media DIY Environment Literature Art Gardening Marketing',
#  'Nature  Gardening Social_Media Parenting',
#  'Science  Travel Literature',
#  'Technology  Fitness Fitness Business Art',
#  'Beauty  Religion Photography Music Sports Environment',
#  'Travel  Technology Science Nature Environment Business Marketing Travel',
#  'Travel  Nature Environment Pop_Culture Art Science Charity Literature Sports',
#  'Food  Education Crafts Food Entertainment Photography',
#  'Food  Parenting Politics Politics',
#  'Politics  Education Religion Environment',
#  'Photography ',
#  'Technology  Beauty Pop_Culture Photography Nature Human_Rights',
#  'Travel  Science Crafts Fitness Politics Literature Charity Beauty Education Parenting Health',
#  'Health  Crafts Nature Photography Photography',
#  'Human_Rights  Music Gaming Environment Beauty Art Art Business Education Music Finance',
#  'Gardening  Fashion Fashion Technology Fitness Pop_Culture Charity Fashion',
#  'Gardening  Art Food',
#  'Science ',
#  'Photography  Human_Rights Environment Science Crafts Social_Media Technology Fashion Education',
#  'Business  Fitness Gardening Politics Politics Crafts Fashion Human_Rights',
#  'Food  Music Pop_Culture Entertainment',
#  'Food  Gardening',
#  'Photography ',
#  'Health  Finance Travel Marketing',
#  'Politics ',
#  'Beauty  Sports Religion Parenting Travel Environment Gaming Human_Rights Marketing Travel',
#  'Crafts  Environment Charity Music Nature Food Literature Art',
#  'Music  Food Pop_Culture Food Art Sports Religion Religion Politics Religion Finance',
#  'Religion  Social_Media Gardening Sports Literature Travel Science Fitness',
#  'Crafts ',
#  'Marketing  Technology DIY Entertainment Finance',
#  'Science  Beauty Photography',
#  'Science  DIY Science Pop_Culture Gaming Art Religion Science',
#  'Finance  Beauty Crafts',
#  'Parenting  Charity Nature',
#  'Crafts  Human_Rights',
#  'Art  Parenting Environment Fashion Science Music Health',
#  'Fitness  Pop_Culture Charity DIY Photography Business Art',
#  'Parenting  Music Nature Health Gardening Sports',
#  'Parenting  Environment Business',
#  'Religion  Sports Gardening Nature Education Entertainment Business',
#  'Food  Health Religion Nature',
#  'Music  Science Environment Technology Nature Fashion Crafts Environment Beauty',
#  'Social_Media  Gaming',
#  'Photography  Human_Rights',
#  'Pop_Culture  Social_Media Environment Fashion Parenting Parenting',
#  'Crafts ',
#  'Technology  Food Beauty Entertainment Travel Fashion',
#  'Charity  Charity Health Business',
#  'Finance  Entertainment Entertainment Literature Gaming Gardening Marketing',
#  'Health ',
#  'Beauty  Environment Photography Crafts Science Technology',
#  'Human_Rights  DIY Marketing Fashion Business Sports',
#  'Crafts ',
#  'Education  Beauty Religion Pop_Culture Social_Media Finance Finance Food',
#  'Music ',
#  'Fashion  Health',
#  'DIY  Art Charity Literature',
#  'Politics  Parenting Music Parenting Music Marketing',
#  'Religion  Pop_Culture Crafts Sports Parenting Science Charity Marketing Art Politics',
#  'Food  Education Nature Parenting Photography Marketing Nature',
#  'Fitness  Religion',
#  'Marketing  Photography Crafts Charity Pop_Culture Social_Media Nature Business Crafts',
#  'Photography  Photography Finance',
#  'Sports  Business Sports Music Finance Human_Rights Social_Media Nature',
#  'Religion ',
#  'Photography  Sports Nature Music',
#  'Art  Fashion Food DIY Parenting Beauty Travel',
#  'Beauty  Marketing Travel Social_Media Technology Parenting Beauty Parenting Marketing Environment Education',
#  'Science  Marketing',
#  'Crafts  Social_Media Social_Media Religion Finance Literature Music Social_Media Literature Fitness',
#  'Travel  Sports Education Fashion Art',
#  'Crafts  Gardening Religion Religion Travel Parenting Finance',
#  'Technology  Technology Food',
#  'Finance  Literature Sports Entertainment Beauty Fashion Beauty Human_Rights Fitness Photography',
#  'Politics  Science',
#  'Health  Health',
#  'Politics  Technology Gaming Food',
#  'Environment  Finance Pop_Culture Gardening Travel Pop_Culture Religion Business',
#  'Literature  Entertainment Fitness Travel Health Gaming Marketing Social_Media Technology Marketing',
#  'Sports ',
#  'Entertainment  Pop_Culture Technology Parenting Human_Rights Entertainment Technology Nature Religion Fashion Food',
#  'Marketing  Technology',
#  'Crafts  Religion Technology Education Crafts Nature Fitness Marketing DIY Charity',
#  'Sports  Art Fitness Fashion Human_Rights Marketing',
#  'Literature  Charity Nature Science Literature Business Technology Nature',
#  'DIY  Marketing Photography Finance Finance Politics Pop_Culture Business Education',
#  'Politics  Gaming Politics Finance Marketing Politics Parenting Education',
#  'Sports  Art DIY Environment Politics Travel Nature Nature Pop_Culture',
#  'Art  Charity Beauty Business Food Gardening Gaming Finance Gaming',
#  'Environment  Crafts Science Gaming Beauty',
#  'Beauty ',
#  'Literature  Beauty Beauty DIY Pop_Culture Health Sports Photography Finance Marketing',
#  'Gardening  Politics Beauty Marketing',
#  'Pop_Culture  Health Gaming Environment',
#  'Crafts  DIY',
#  'Beauty  Photography Travel Pop_Culture Pop_Culture Photography Technology Music Food Food Health',
#  'Food  Charity Human_Rights Parenting Science Photography Human_Rights Social_Media Literature',
#  'Fitness  Human_Rights Technology Crafts DIY',
#  'Travel  Entertainment Technology Marketing Beauty Literature Music Photography Social_Media Fitness Parenting',
#  'Technology  Nature Fashion Music Finance Education Art DIY Religion',
#  'Technology  Education Human_Rights DIY Sports Music Education',
#  'Education  Environment Nature Human_Rights Fashion Parenting Finance Environment Pop_Culture',
#  'Music  Charity Gaming DIY Fitness Art',
#  'DIY  Gaming Beauty Environment Crafts Human_Rights Fashion Travel Finance Sports Gaming',
#  'Finance  Gaming Art Literature Health Parenting Education Health Marketing',
#  'Human_Rights  Pop_Culture',
#  'Art ',
#  'Politics  Photography DIY',
#  'Religion  Technology Religion Marketing Environment Crafts Entertainment',
#  'Environment  Finance Literature Technology',
#  'Fitness  Education Crafts Science Environment',
#  'Technology  Finance Business',
#  'Food  Education Food Sports Art Literature',
#  'Music  Politics Religion Food Religion Pop_Culture Photography',
#  'Marketing  Music Crafts Gardening Health DIY Marketing',
#  'Technology  Business Beauty Entertainment Nature Business Photography Parenting Business Marketing Social_Media',
#  'Human_Rights  Music Parenting Entertainment Science Crafts DIY Travel Art Fitness',
#  'Politics  Human_Rights Art Fashion Human_Rights Crafts Human_Rights',
#  'Social_Media  Entertainment Crafts Pop_Culture Travel Parenting Charity Travel Charity',
#  'DIY  Health Human_Rights Environment Fitness Fitness Technology Business Social_Media',
#  'Technology  Music Health',
#  'Environment  Literature',
#  'Technology  Gardening Gaming',
#  'Gaming  Social_Media Travel Human_Rights Pop_Culture DIY Photography Fitness Technology Photography',
#  'Technology ',
#  'Social_Media  Marketing Environment Music Health Gaming Beauty Finance Social_Media Health',
#  'Education  Food Music Gaming Music Health Fashion Marketing Human_Rights',
#  'Fitness  Religion Food Literature Science Nature Gardening',
#  'DIY  Sports Literature',
#  'Fitness ',
#  'Gardening  DIY Fitness Fashion Gaming Art',
#  'Entertainment ',
#  'Health  Photography Gaming',
#  'Art  Travel Education Food Charity Gaming Charity',
#  'Human_Rights  Nature Health Technology Education',
#  'Fitness  DIY Food Charity Finance Fitness',
#  'Finance  Business Fitness Travel',
#  'Technology  Technology Literature Entertainment Nature Gaming Gardening Social_Media Charity Literature',
#  'Sports  Sports Politics',
#  'Fitness  Music Crafts',
#  'Technology  Fashion Human_Rights Finance Beauty Literature Social_Media Technology Parenting Business Beauty',
#  'Business  Pop_Culture Crafts Environment DIY Travel Music Pop_Culture Pop_Culture',
#  'Business  Entertainment Beauty Photography Science Environment Finance Fashion',
#  'Human_Rights  Business Finance Sports Religion Human_Rights Sports Sports Environment',
#  'Travel  Marketing Gardening',
#  'Food  Music Politics Food',
#  'Human_Rights  Music Literature Parenting Human_Rights Politics Charity Entertainment Food Photography Art',
#  'Gaming  Technology Fitness',
#  'Nature  Photography Nature Gardening Pop_Culture',
#  'Literature  Human_Rights Nature Environment DIY Finance Beauty',
#  'Fashion  Charity Science Gaming Politics Art Pop_Culture Environment Gaming',
#  'Environment  Gardening Fashion Pop_Culture Business Photography Music',
#  'Marketing  Business Art Pop_Culture Sports Science Social_Media Marketing Music',
#  'Marketing  Music Music Education Music Food Nature Pop_Culture Music Politics Food',
#  'Education  Sports',
#  'Fitness  Food Sports Fitness Parenting Photography Nature Photography Sports DIY',
#  'Finance  Religion Business Social_Media Health Crafts Education Beauty',
#  'Fashion  DIY Environment',
#  'Gaming  Social_Media Charity Business Photography Sports Art',
#  'Technology  Social_Media Crafts Religion Sports Nature Entertainment Environment',
#  'Parenting  Pop_Culture Politics',
#  'Parenting  Photography',
#  'Social_Media  Health DIY Environment Gaming Science Health Gaming Education Politics Religion',
#  'Science  Technology Finance Art Technology Religion Beauty',
#  'Beauty  Photography Marketing Gardening',
#  'Nature  Entertainment',
#  'Finance  Travel',
#  'Parenting  Marketing Travel Charity Science Science Education Music',
#  'Charity  Art Literature Photography Environment Education Literature Education Music',
#  'Art  Crafts',
#  'Pop_Culture  Food Travel Parenting Finance Human_Rights',
#  'Beauty  Travel',
#  'Environment  Finance Photography Music Religion Crafts Environment Parenting',
#  'Photography  Health Finance Art Marketing Beauty',
#  'Parenting  Science',
#  'Finance  Beauty Photography Finance Travel Fitness Photography Gardening Parenting Music Photography',
#  'Religion  Science',
#  'Art  Politics Social_Media Marketing',
#  'Nature  Music Sports',
#  'Finance  Science Art',
#  'Health ',
#  'Fashion  Politics Gaming Beauty Literature Religion',
#  'Marketing  Travel Business Education Art DIY Photography Politics Photography Music Marketing',
#  'Politics  Photography Photography Politics Business Entertainment Photography Sports',
#  'Human_Rights  DIY Sports Photography Gardening Pop_Culture DIY Science Photography',
#  'Health  Environment Human_Rights Politics Politics Nature Parenting Education',
#  'Education  Pop_Culture Gaming Environment',
#  'Literature  Photography Social_Media',
#  'Nature  Gardening Gardening Pop_Culture Parenting',
#  'Food  Crafts Gaming',
#  'DIY  Human_Rights Nature Art Sports Parenting Crafts Social_Media Environment Religion',
#  'Human_Rights ',
#  'Food  Politics Crafts Gardening Beauty',
#  'Art  Technology Gaming Food Nature Gardening Food',
#  'Gaming  Environment Literature Sports Pop_Culture Social_Media Music Pop_Culture Parenting Entertainment Science',
#  'Finance  Gardening Pop_Culture Environment Gaming DIY Music Crafts',
#  'Gardening  Parenting Social_Media Entertainment Fitness Pop_Culture Entertainment Gardening Gardening',
#  'Environment  Education Human_Rights Politics Health Health Religion Food Travel Music Music',
#  'Photography  Social_Media Pop_Culture Technology Human_Rights Travel Charity Music',
#  'Science  Education Photography Charity Beauty',
#  'Gardening  Travel',
#  'Art ',
#  'Finance  Crafts Technology Travel Art Sports Nature Social_Media DIY Environment Health',
#  'Nature ',
#  'Religion  Art Art',
#  'Gardening  Crafts Music Entertainment DIY Business Crafts Education Music Science Science',
#  'Entertainment  Fashion',
#  'Education  Charity',
#  'Food  Religion',
#  'Health  Art Business Entertainment Gardening',
#  'Science  Business',
#  'Parenting  Education Health Pop_Culture Environment Environment Nature',
#  'Charity ',
#  'Fitness  Fashion Fashion Environment Sports Social_Media Health Art',
#  'Music  Charity Sports Marketing',
#  'Gaming  Religion Business Science Science',
#  'Art  Fitness DIY Music',
#  'Gaming  Nature Sports Human_Rights Environment Nature Music Education Crafts Technology Fitness',
#  'Pop_Culture  Science Finance Science Human_Rights Fashion',
#  'Education ',
#  'Human_Rights  Gaming Food Health Music Music Fashion Fitness Health',
#  'Photography  Art Food Religion Fashion',
#  'Environment  Literature Fashion Parenting Environment Fitness Music Sports Human_Rights',
#  'Education  Science Business Human_Rights Religion Human_Rights',
#  'Human_Rights  Literature Sports DIY Travel',
#  'DIY  Charity Literature Crafts Politics Fashion Politics',
#  'Gaming  Parenting Gardening Food Sports Health',
#  'Science  Beauty Health Social_Media Social_Media Travel Fashion Beauty',
#  'Finance  Education Business DIY Nature Religion Charity',
#  'Gardening ',
#  'Photography  Business Politics Marketing Literature Sports Finance Marketing Science DIY Fitness',
#  'Fitness ',
#  'Politics  Fitness Literature Environment Sports Music Fitness Music',
#  'DIY  Health Finance Travel Marketing Pop_Culture Religion Food Travel Finance Literature',
#  'Music  Politics Charity Food Religion Fashion Technology Charity Art',
#  'Music  Finance Food Business Literature Gardening Nature Pop_Culture Parenting Fashion',
#  'Politics  Science Parenting Marketing Sports Health Charity',
#  'Crafts  Crafts Social_Media Entertainment Religion Human_Rights Marketing',
#  'Charity  Business Parenting Social_Media Entertainment Religion Technology Beauty',
#  'Food  Gaming Science Education Food Entertainment Music Sports',
#  'Food  Crafts Finance DIY Art Nature Fitness Fitness',
#  'Sports  Business Education Finance Literature Business Marketing Parenting Politics',
#  'Religion  Crafts Technology Health Beauty Fitness Photography',
#  'Music ',
#  'Business  Beauty Social_Media Food Literature Travel Sports',
#  'Environment  Religion Beauty Business',
#  'Parenting  Nature Health Photography',
#  'Sports  Fitness Travel',
#  'Parenting  Business Human_Rights Human_Rights Environment',
#  'Charity ',
#  'Nature  Science Art Nature Technology Finance',
#  'Travel ',
#  'Parenting  Parenting Parenting',
#  'Health  Religion Fitness Religion']

# %% [markdown]
# Things to tweak:
#
# - min_df
#   - only considers matches that occurs n times in document.
# - ngram_range
#   - specify tuple of ngram. ngram checks n consecutive words. (ex: (1,10))
# - stop_words
#   - list of ignored words. specify a list of strings or a language in string. (ex: 'english')
# - min_df_multiplier
#   - min_df starts from length of data then gradually decreases by multiplier.

# %% [markdown]
# ## Train Data

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Function to get the top n recommendations for a given document index
def get_recommendations_tfidf(new_data, data, top_n=1, min_df_multiplier=.4):
    copied_data = data.copy()
    copied_data.append(new_data)
    # Create the vectorizer
    try_min_df = len(copied_data)
    while True:
      try:
        vectorizer = TfidfVectorizer(stop_words='english',ngram_range=(1,10),min_df=try_min_df,analyzer='word')
        # Fit and transform the data
        X = vectorizer.fit_transform(copied_data)
        break
      except Exception as e:
        try_min_df = int(try_min_df * min_df_multiplier)
    # Compute the pairwise cosine similarity
    cosine_sim = cosine_similarity(X)
    # Get the pairwise cosine similarity scores for the document
    sim_scores = list(enumerate(cosine_sim[-1]))
    # exclude the new data from sim score
    sim_scores = sim_scores[:-1]
    # Sort the documents by similarity score in descending order
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    # Get the top n recommendations
    top_docs = sim_scores[:top_n+1]
    # Return the indices of the recommended documents
    return [[copied_data[i],i,j] for i, j in top_docs]

recs = get_recommendations_tfidf('{Gaming  Art Charity Art Politics Art Business}', data, top_n=5)
recs
# Out:
# [['{Art  Sports}', 165, 0.8661109319480946],
#  ['{Art }', 280, 0.8661109319480946],
#  ['{Art  Education}', 987, 0.8661109319480946],
#  ['{Art  Gaming Education}', 240, 0.8165844069778043],
#  ['{Art  Education Art Fitness}', 952, 0.7786823247416116],
#  ['{Environment  Art Charity Art Health}', 908, 0.763730826113787]]

# %%
import tensorflow as tf

# Function to get the top n recommendations for a given document index
def get_recommendations_tfidf(new_data, data, top_n=1, min_df_multiplier=0.4, output_mode='tf-idf'):
    copied_data = data.copy()
    copied_data.append(new_data)

    # Create the TextVectorization layer
    vectorizer = tf.keras.layers.experimental.preprocessing.TextVectorization(
        max_tokens=None,  # Default value, no maximum limit on vocabulary size
        output_mode=output_mode,
        output_sequence_length=None,  # Default value, variable length sequences
        pad_to_max_tokens=False,  # Don't pad sequences
        standardize='lower_and_strip_punctuation',  # Disable standardization
        split='whitespace',  # Split text by whitespace
    )

    # Fit and transform the data
    vectorizer.adapt(copied_data)
    X = vectorizer(copied_data)

    # Compute the pairwise cosine similarity
    cosine_sim = tf.linalg.matmul(X, X, transpose_b=True)

    # Get the pairwise cosine similarity scores for the document
    sim_scores = list(enumerate(cosine_sim[-1, :-1]))

    # Sort the documents by similarity score in descending order
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the top n recommendations
    top_docs = sim_scores[:top_n]

    # Return the indices and recommendations
    return [[copied_data[i], i, float(j)] for i, j in top_docs]

def loop_print(arr,contains):
  for el in arr:
    print(el)
  print(len(set(i[0] for i in arr) & contains))
  print()

def check_contains(raw_string):
  words = raw_string.replace("{",'').replace("}",'').split()
  output = set()
  for datum in data:
    cont = False
    for word in words:
      if word not in datum:
        cont = True
        break
    if cont:
      continue
    output.add(datum)
  for i in output:
    print(i)
  print()
  return output

query = '{Politics  Social_Media}'

output = check_contains(query)

recs = get_recommendations_tfidf(query, data, top_n=10)
loop_print(recs, output)
recs = get_recommendations_tfidf(query, data, top_n=10, output_mode='int')
loop_print(recs, output)
recs = get_recommendations_tfidf(query, data, top_n=10, output_mode='count')
loop_print(recs, output)
recs = get_recommendations_tfidf(query, data, top_n=10, output_mode='multi_hot')
loop_print(recs, output)
# Out:
# {Nature  Social_Media Politics DIY Fitness Parenting Environment Crafts Environment Technology Parenting}
# {Politics  DIY Marketing Beauty Social_Media Entertainment Crafts Parenting Politics Travel}
# {Social_Media  Politics Food Photography Beauty Science Beauty Gaming Sports}
# {Charity  Environment Politics Crafts Social_Media}
# {Politics  Music Social_Media Health Health Charity Fitness}
# {DIY  Literature Gardening Art Politics Technology Social_Media Gaming Travel Gardening Marketing}
# {Environment  Politics Business Fashion Crafts Social_Media Food Food}
# {Gardening  Human_Rights Politics Technology Social_Media Art Marketing Marketing Technology}
# {Technology  Gardening Business Politics Food Nature Fashion Social_Media}
# {Art  Social_Media Fashion Human_Rights Education Photography Technology Charity Gaming Entertainment Politics}
# {Entertainment  Politics Environment Sports Photography Social_Media Fitness}
# ['{Politics  DIY Marketing Beauty Social_Media Entertainment Crafts Parenting Politics Travel}', 40, 3.0]
# ['{Health  Human_Rights Politics Politics Environment Education Politics}', 549, 3.0]
# ['{Social_Media  Charity Social_Media Crafts Health Gardening Social_Media}', 691, 3.0]
# ['{Social_Media  Parenting Social_Media Finance Beauty Crafts Charity Pop_Culture Social_Media Gardening}', 704, 3.0]
# ['{Politics  Environment Crafts Environment Photography Politics Politics}', 719, 3.0]
# ['{Fashion  Science Social_Media Pop_Culture Entertainment Social_Media Politics Gardening Pop_Culture Entertainment}', 727, 3.0]
# ['{Social_Media  Technology Food Politics Charity Politics Travel Marketing Photography}', 766, 3.0]
# ['{Technology  Travel Photography Social_Media Art Social_Media Parenting Pop_Culture Finance Human_Rights}', 6, 2.0]
# ['{Politics  Nature Health Beauty Music Finance Finance Music Health Politics Crafts}', 7, 2.0]
# ['{Charity  Environment Sports Politics Fashion Education Social_Media Marketing}', 22, 2.0]
# 4
#
# ['{Charity  Environment Sports Politics Fashion Education Social_Media Marketing}', 22, 2.0]
# ['{Travel  Photography Pop_Culture Social_Media DIY Fashion Nature Food Music Politics}', 34, 2.0]
# ['{Politics  DIY Marketing Beauty Social_Media Entertainment Crafts Parenting Politics Travel}', 40, 2.0]
# ['{Charity  Environment Politics Crafts Social_Media}', 45, 2.0]
# ['{Technology  Gardening Business Politics Food Nature Fashion Social_Media}', 117, 2.0]
# ['{Photography  Politics Travel Travel Crafts Environment Social_Media Crafts}', 177, 2.0]
# ['{Nature  Politics Social_Media Food Nature Education}', 191, 2.0]
# ['{Art  Social_Media Fashion Human_Rights Education Photography Technology Charity Gaming Entertainment Politics}', 231, 2.0]
# ['{Food  Social_Media Fashion Politics Health Sports}', 235, 2.0]
# ['{Environment  Charity Food Crafts Social_Media Finance Photography Politics}', 271, 2.0]
# 10

# %% [markdown]
# # Advantages of Using TFIDF
# - Accounts unavailable tag combination
# - Penalties for each tag miss. If all tags are matched but aforementioned events have many more general tags, it will score/match less.

# %%
newdata = data.copy()
newdata = [i.replace('{','').replace('}','').split(',') for i in newdata]
predict = '{Music,Business,Art,Education,Art,Crafts,Social Media}'
predict = predict.replace('{','').replace('}','').split(',')
count = [len([i for i in predict if i in j]) for j in newdata]
match_list = [i for i, x in enumerate(count) if x == max(count)]
[data[i] for i in match_list]
# Out:
# ['{Music,Business,Art,Education,Art,Crafts,Social Media,Marketing,Art,Sports,Health}']

# %%
import pickle
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Function to train and save the TfidfVectorizer and cosine similarity model
def train_tfidf(data, save_path, ngram_range=(1, 1), stop_words=None, min_df_multiplier=.4):
    # Create the vectorizer
    try_min_df = len(data)
    while True:
      try:
        vectorizer = TfidfVectorizer(stop_words=stop_words,ngram_range=ngram_range,min_df=try_min_df,analyzer='word')
        # Fit and transform the data
        X = vectorizer.fit_transform(data)
        break
      except Exception as e:
        try_min_df = int(try_min_df * min_df_multiplier)
    # Compute the pairwise cosine similarity
    cosine_sim = cosine_similarity(X)
    # Save the vectorizer and cosine similarity matrix to disk
    with open(save_path, 'wb') as f:
        pickle.dump((vectorizer, cosine_sim), f)

# Function to load the TfidfVectorizer and cosine similarity model from disk
def load_tfidf(save_path):
    with open(save_path, 'rb') as f:
        vectorizer, cosine_sim = pickle.load(f)
    return vectorizer, cosine_sim

# Function to get the top n recommendations for a given document index
def get_recommendations_tfidf(new_data, vectorizer, cosine_sim, data, top_n=1):
    copied_data = data.copy()
    copied_data.append(new_data)
    # Transform the new data using the pre-trained vectorizer
    X_new = vectorizer.transform(copied_data)
    # Compute the pairwise cosine similarity between the new data and the training data
    cosine_sim_new = cosine_similarity(X_new)
    # Get the pairwise cosine similarity scores for the document
    sim_scores = list(enumerate(cosine_sim_new[-1]))
    # exclude the new data from sim score
    sim_scores = sim_scores[:-1]
    # Sort the documents by similarity score in descending order
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    # Get the top n recommendations
    top_docs = sim_scores[:top_n]
    # Return the indices of the recommended documents
    return [(copied_data[i], i, j) for i, j in top_docs]

# Train and save the model
train_tfidf(data, 'tfidf_model.pkl', ngram_range=(1, 10), stop_words='english')

# Load the model
vectorizer, cosine_sim = load_tfidf('tfidf_model.pkl')

# Use the model to make recommendations
recs = get_recommendations_tfidf('Business Music', vectorizer, cosine_sim, data, top_n=5)
for i in recs:
    print(i)
# Out:
# ('{Business}', 52, 1.0)
# ('{Business}', 59, 1.0)
# ('{Business}', 356, 1.0)
# ('{Business}', 469, 1.0)
# ('{Business}', 788, 1.0)

# %% [markdown]
# ## Export Model

# %%
from sklearn.model_selection import train_test_split

# Split the data into train and test sets
train_data, test_data = train_test_split(data, test_size=0.2, random_state=42)

# Tokenize the train and test data
tokenizer = tf.keras.preprocessing.text.Tokenizer(filters='- ',lower=True)
tokenizer.fit_on_texts(train_data)
train_sequences = tokenizer.texts_to_sequences(train_data)
test_sequences = tokenizer.texts_to_sequences(test_data)

# Pad the train and test sequences
max_len = max([len(seq) for seq in train_sequences + test_sequences])
train_padded_sequences = tf.keras.preprocessing.sequence.pad_sequences(train_sequences, maxlen=max_len, padding='post')
test_padded_sequences = tf.keras.preprocessing.sequence.pad_sequences(test_sequences, maxlen=max_len, padding='post')

# Define the TensorFlow model
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=1, input_length=max_len),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(1024, activation='relu'),
    tf.keras.layers.Dense(len(data), activation='softmax')
])

optimizer = tf.keras.optimizers.Adagrad(learning_rate=0.5, initial_accumulator_value=0.1)

# Compile the model
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(train_padded_sequences, np.arange(len(train_data)), epochs=10)

# Evaluate the model on the test set
train_loss, train_accuracy = model.evaluate(train_padded_sequences, np.arange(len(train_data)))
print("Train loss:", train_loss)
print("Train accuracy:", train_accuracy)
test_loss, test_accuracy = model.evaluate(test_padded_sequences, np.arange(len(test_data)))
print("Test loss:", test_loss)
print("Test accuracy:", test_accuracy)

# %%
recs = get_recommendations_tf('Beauty DIY Education', data, top_n=5)
for i in recs:
  print(i)
